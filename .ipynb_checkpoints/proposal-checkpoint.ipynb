# %% [markdown]
# # Project Code
# Group Member: Layton Liu, Tommy Kong, Gary Lin
#
# Objective: In this project, we will analyze the aviation accident over 1919-2023 and the causing factors behind.
#
# Source: https://www.kaggle.com/datasets/warcoder/civil-aviation-accidents

# %% [markdown]
# ## 1. Data Aggregation

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import geopandas
from pandas_datareader import wb

# %% [markdown]
# Since the data contains some incomprehensible value, we need to eliminate them first.

# %%
naValues = ['date unk.', 'unknown', 'Unknown country', '?']
data = pd.read_csv('aviation-accident.csv', na_values=naValues)
print(f'Original shape: {data.shape}')
data.dropna(subset=['date', 'fatalities', 'country'], axis=0, inplace=True)
data.shape
# Out:
# Original shape: (23917, 9)
# (19825, 9)

# %% [markdown]
# The values in "fatalities" and "categories" are hard to read, thus we developed three functions to help us handle these values. We also developed an extra function to get the "season" when the accident happened based on the "date". These four functions are shown as follows:

# %%
def toInt(strValue):
    try:
        intValue = int(strValue)
        return intValue
    except Exception:
        return sum(map(int, re.findall('\d+', strValue)))

# %%
def catDetails(strValue):
    accidentCat = {'A': 'Accident', 'I': 'Incident', 'H': 'Hijacking', 'C': 'Criminal Occurrence', 'O': 'Other Occurrence', 'U': 'Unknown'}
    convertedValue = ''

    convertedValue += accidentCat.get(strValue[0])

    return convertedValue

# %%
def damDetails(strValue):
    accidentDam = {'1': 'hull-loss', '2': 'repairable damage'}
    convertedValue = ''

    convertedValue += accidentDam.get(strValue[1])

    return convertedValue

# %%
def getSeason(date):
    month = date.month

    if month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Fall'
    elif month in [12, 1, 2]:
        return 'Winter'

# %% [markdown]
# Before analyzing the data, we organized it to increase readablity.

# %%
data['year'] = data['year'].astype(int)
data['date'] = pd.to_datetime(data['date'], format='%d-%b-%Y', errors='coerce')
data['fatalities'] = data['fatalities'].map(toInt)
data = data.rename(columns={'cat':'category'})
data['damage'] = data['category'].map(damDetails)
data['category'] = data['category'].map(catDetails)
data['season'] = data['date'].map(getSeason)

# %%
data = data.set_index(['year'])
data.head()
# Out:
#            date                type registration                operator  \
# year
# 1919 1919-08-02       Caproni Ca.48          NaN                 Caproni
# 1919 1919-08-11     Felixstowe Fury         N123                     RAF
# 1920 1920-02-23    Handley Page O/7       G-EANV  Handley Page Transport
# 1920 1920-02-25  Handley Page O/400       G-EAMC  Handley Page Transport
# 1920 1920-06-30  Handley Page O/400       G-EAKE  Handley Page Transport
#
#       fatalities             location       country  category     damage  \
# year
# 1919          14               Verona         Italy  Accident  hull-loss
# 1919           1  near Felixtowe RNAS          U.K.  Accident  hull-loss
# 1920           0  Acadia Siding, C...  South Africa  Accident  hull-loss
# 1920           0      near El Shereik         Sudan  Accident  hull-loss
# 1920           0             ÃstanÃ¥        Sweden  Accident  hull-loss
#
#       season
# year
# 1919  Summer
# 1919  Summer
# 1920  Winter
# 1920  Winter
# 1920  Summer

# %%
data.to_csv('cleaned.csv')
data.dtypes
# Out:
# date            datetime64[ns]
# type                    object
# registration            object
# operator                object
# fatalities               int64
# location                object
# country                 object
# category                object
# damage                  object
# season                  object
# dtype: object

# %% [markdown]
# ## 2. Quantitative Analysis

# %%
fig, ax = plt.subplots(figsize=(20,5))
ax.hist(data.index, bins=data.iloc[-1].name-data.iloc[0].name, width=0.8)

ax.set_xticks(np.arange(1920, 2023, 5))
ax.set_ylim(0, 700)
plt.axvspan(1939, 1945, color='grey', alpha=0.5)

ax.set_title('Civil Aviation Accidents')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.annotate('WWII', xy=(1939, 500), xytext=(1930, 600), arrowprops={'facecolor':'black',  'arrowstyle':'->'})

plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,5))
ax.bar(data.groupby(data.index).sum().index, data.groupby(data.index).sum()['fatalities'], color='steelblue')

ax.set_xticks(np.arange(1920, 2023, 5))
ax.set_ylim(0, 4500)
plt.axvspan(1939, 1945, color='grey', alpha=0.5)

ax.set_title('Civil Aviation Accident Fatalities')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.annotate('WWII', xy=(1939, 3200), xytext=(1930, 3800), arrowprops={'facecolor':'black',  'arrowstyle':'->'})

sns.despine(ax=ax)

# %%
accidents_season = data.groupby(data['season']).count().sort_values(by=['season'], key=lambda x: x.map({'Spring':1, 
                                                                                                      'Summer':2, 
                                                                                                      'Fall':3, 'Winter':4}))

fig, ax = plt.subplots(figsize=(10,5))
bars = ax.bar(accidents_season.index, accidents_season['fatalities'], color='steelblue')

ax.set_ylim(0, 6000)

ax.set_title('Civil Aviation Accidents in Each Season')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

for i, bar in enumerate(bars):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
            str(int(accidents_season['fatalities'][i])), ha='center', va='bottom', fontsize=10)

plt.show()

# %%
accidents_category = data.groupby(data['category']).count()[['fatalities']]
accidents_category = accidents_category.rename(columns = {'fatalities': 'accidents'})

fig, ax = plt.subplots(figsize=(10,5))
bars = ax.bar(accidents_category.index, accidents_category['accidents'], color='steelblue')

ax.set_title('Civil Aviation Accidents for Each Category')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

for i, bar in enumerate(bars):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
            str(int(accidents_category['accidents'][i])), ha='center', va='bottom', fontsize=10)
    
plt.show()

# %%
fatalities_category = data.groupby(data['category']).sum()[['fatalities']]

fig, ax = plt.subplots(figsize=(10,5))
bars = ax.bar(fatalities_category.index, fatalities_category['fatalities'], color='steelblue')

ax.set_title('Civil Aviation Accidents Fatalities for Each Category')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

for i, bar in enumerate(bars):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
            str(int(fatalities_category['fatalities'][i])), ha='center', va='bottom', fontsize=10)
    
plt.show()

# %%
fatality_rate = pd.merge(left=accidents_category, right=fatalities_category, left_index=True, right_index=True, how='outer')
fatality_rate['fatality_rate'] = fatality_rate['fatalities']/fatality_rate['accidents']
fatality_rate
# Out:
#                      accidents  fatalities  fatality_rate
# category
# Accident                 16687      119672       7.171571
# Criminal Occurrence       1048        9030       8.616412
# Hijacking                 1066        3770       3.536585
# Incident                    15           0       0.000000
# Other Occurrence           970          77       0.079381
# Unknown                     39           0       0.000000

# %%
total_hullloss = data[data['damage'] == 'hull-loss'].groupby('year').count()[['damage']]
total_hullloss = total_hullloss.rename(columns = {'damage': 'hull-loss'})

total_accident = data.groupby('year').count()[['damage']]
total_accident = total_accident.rename(columns = {'damage': 'accident'})

hullloss_rate = pd.merge(left=total_hullloss, right=total_accident, left_index=True, right_index=True, how='outer')
hullloss_rate['hull-loss rate'] = hullloss_rate['hull-loss']/hullloss_rate['accident']

fig, ax = plt.subplots(figsize=(15,7))
ax.plot(hullloss_rate.index, hullloss_rate['hull-loss rate']*100, color='red', label='Hull-loss rate')

ax.set_title('Hull-loss vs. Total Accidents')
ax.set_ylabel('Probability (%)')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.legend(loc='upper right')

plt.show()

# %%
fatal = data.groupby('country').sum().sort_values(by='fatalities', ascending=False)
fatal.reset_index(inplace=True)
fatal.head(3)
# Out:
#   country  fatalities
# 0     USA       19298
# 1  Russia        9973
# 2  Brazil        3528

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
world.head(3)
# Out:
#       pop_est continent       name iso_a3  gdp_md_est  \
# 0    889953.0   Oceania       Fiji    FJI        5496
# 1  58005463.0    Africa   Tanzania    TZA       63177
# 2    603253.0    Africa  W. Sahara    ESH         907
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...

# %%
world_test = pd.merge(left=world, right=fatal, how='outer', left_on=['name'], right_on=['country'], indicator=True)
world_test
# Out:
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI      5496.0
# 1     58005463.0         Africa                  Tanzania    TZA     63177.0
# 2       603253.0         Africa                 W. Sahara    ESH       907.0
# 3     37589262.0  North America                    Canada    CAN   1736425.0
# 4    328239523.0  North America  United States of America    USA  21433226.0
# ..           ...            ...                       ...    ...         ...
# 245          NaN            NaN                       NaN    NaN         NaN
# 246          NaN            NaN                       NaN    NaN         NaN
# 247          NaN            NaN                       NaN    NaN         NaN
# 248          NaN            NaN                       NaN    NaN         NaN
# 249          NaN            NaN                       NaN    NaN         NaN
#
#                                               geometry         country  \
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...            Fiji
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...        Tanzania
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...             NaN
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...          Canada
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...             NaN
# ..                                                 ...             ...
# 245                                               None  Christmas Isl.
# 246                                               None     Cayman Isl.
# 247                                               None      Seychelles
# 248                                               None          B.V.I.
# 249                                               None   French Guiana
#
#      fatalities      _merge
# 0          56.0        both
# 1         117.0        both
# 2           NaN   left_only
# 3        2353.0        both
# 4           NaN   left_only
# ..          ...         ...
# 245         0.0  right_only
# 246         0.0  right_only
# 247         0.0  right_only
# 248         0.0  right_only
# 249         0.0  right_only
#
# [250 rows x 9 columns]

# %%
problematic_name = world_test.loc[world_test['_merge'] == 'right_only']['country']
problematic_name.to_csv('problematic_names.csv', index=False)
world_test.loc[world_test['_merge'] == 'left_only']['name']
# Out:
# 2                     W. Sahara
# 4      United States of America
# 7              Papua New Guinea
# 11              Dem. Rep. Congo
# 20                 Falkland Is.
# 23       Fr. S. Antarctic Lands
# 24                  Timor-Leste
# 60                Côte d'Ivoire
# 66         Central African Rep.
# 73                     eSwatini
# 79                    Palestine
# 84         United Arab Emirates
# 135                 Solomon Is.
# 143              United Kingdom
# 149                      Brunei
# 153                     Czechia
# 160                   N. Cyprus
# 167                  Somaliland
# 170            Bosnia and Herz.
# 175         Trinidad and Tobago
# 176                    S. Sudan
# Name: name, dtype: object

# %%
name_dict = { 'Western Sahara': 'W. Sahara', 'USA': 'United States of America', 'P.N. Guinea': 'Papua New Guinea',
              'D.R. Congo': 'Dem. Rep. Congo', 'Falkland Isl.': 'Falkland Is.', 'Timor': 'Timor-Leste', 
              'Cote d\'Ivoire': 'Côte d\'Ivoire', 'C.A.R.': 'Central African Rep.', 'Eswatini': 'eSwatini',
              'U.A.E.': 'United Arab Emirates', 'Solomon Isl.': 'Solomon Is.', 'U.K.': 'United Kingdom', 
              'Czech Rep.': 'Czechia', 'Bosnia': 'Bosnia and Herz.', 'Trinidad & Tobago': 'Trinidad and Tobago',
              'South Sudan': 'S. Sudan'}

# %%
for country in fatal['country']:
    if country in name_dict:
        fatal['country'] = fatal['country'].replace(name_dict)
fatal = fatal.rename(columns = {'country': 'name'})
world = pd.merge(left=world, right=fatal, how='outer', on='name', indicator=True)

# %%
fig, ax = plt.subplots(figsize=(15, 7))
ax.set_title('World Population')
world.plot(column='fatalities', cmap='Reds', ax=ax, legend=True, edgecolor='black', vmin=0, vmax=11500)
plt.show()

# %% [markdown]
# ## 3. Probability Analysis

# %%
# Aggregate fatalities and accidents data
world_agg_data = data.groupby(data.index)['fatalities'].agg(['count', 'sum']).rename(columns={'count':'accidents', 'sum':'fatalities'})

# Get total departures and passengers data from world bank
departures = wb.download(indicator='IS.AIR.DPRT', country=['ALL'], start=1970, end=2020)
departures.index.set_levels(departures.index.levels[1].astype(int), level=1, inplace=True)
passengers = wb.download(indicator='IS.AIR.PSGR', country=['ALL'], start=1970, end=2020)
passengers.index.set_levels(passengers.index.levels[1].astype(int), level=1, inplace=True)

# Merge these two datasets
merged = pd.merge(left=departures.xs('World'), right=world_agg_data, left_index=True, right_index=True, how='inner')
merged = pd.merge(left=passengers.xs('World'), right=merged, left_index=True, right_index=True, how='inner')
merged.rename(columns={'IS.AIR.PSGR':'passengers', 'IS.AIR.DPRT':'departures'}, inplace=True)
merged.head(3)
# Out:
# C:\Users\prime\AppData\Local\Temp\ipykernel_49304\2469290723.py:6: FutureWarning: inplace is deprecated and will be removed in a future version.
#   departures.index.set_levels(departures.index.levels[1].astype(int), level=1, inplace=True)
# C:\Users\prime\AppData\Local\Temp\ipykernel_49304\2469290723.py:8: FutureWarning: inplace is deprecated and will be removed in a future version.
#   passengers.index.set_levels(passengers.index.levels[1].astype(int), level=1, inplace=True)
#         passengers    departures  accidents  fatalities
# year
# 2020  1.809389e+09  2.045848e+07        198         430
# 2019  4.557606e+09  3.920377e+07        245         471
# 2018  4.242448e+09  3.682823e+07        232         963

# %%
# Are we less likely to encounter an accident?
fig, ax = plt.subplots(figsize=(15,7))
ax2 = ax.twinx()
ax.plot(merged.index, merged['accidents'], color='red', label='Accidents')
ax2.plot(merged.index, merged['departures'], color='blue', label='Departures')
ax.set_xticks(np.arange(1970, 2021, 5))
ax.set_title('Civil Aviation Accidents vs. Departures')
ax.set_ylabel('Number of Flights')
ax.spines['top'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.show()

# %%
# Are we less likely to die to a flight accident
fig, ax = plt.subplots(figsize=(15,7))
ax2 = ax.twinx()
ax.plot(merged.index, merged['fatalities'], color='red', label='Fatalities')
ax2.plot(merged.index, merged['passengers'], color='blue', label='Passengers')
ax.set_xticks(np.arange(1970, 2021, 5))
ax.set_title('Civil Aviation Fatalities vs. Passengers')
ax.set_ylabel('Number of Passengers')
ax.spines['top'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.show()

# %%
# How have these two probabilities envolved
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(merged.index, merged['accidents']/merged['departures']*100, color='red', label='Accident rate')
ax.plot(merged.index, merged['fatalities']/merged['passengers']*100, color='blue', label='Fatality rate')
ax.set_xticks(np.arange(1970, 2021, 5))
ax.set_title('Civil Aviation Accident rate vs. Fatality rate')
ax.set_ylabel('Probability (%)')
plt.ticklabel_format(style='plain', axis='y', useOffset=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.legend(loc='upper right')
plt.show()

# %%
# Unfortunately we encounter an accident, are we less likely to die to it
fig, ax = plt.subplots(figsize=(15,7))
sns.regplot(x=merged.index, y=merged['fatalities']/merged['accidents'], data=merged, scatter=False, color='gray')
ax.plot(merged.index, merged['fatalities']/merged['accidents'], color='red', label='Accidents')
ax.set_title('Average Fatalities per Accident')
ax.set_ylabel('Number of Passengers')
sns.despine()
plt.show()
